# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.9 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive
# Out:
#  1.jpg	      Classroom			       'RapportJihene (2).docx'
#  2.jpg	     'Colab Notebooks'		        tache.jpg
#  3.jpg	      Decodeur7s.gdoc		        tp2cao.docx
#  4.jpg	      D.v1i.yolo26		       'tp4 (1).ipynb'
#  5.jpg	     'final jeans defects.v1i.yolov8'  'TP N4.docx'
#  6.jpg	      jean1.jpg			        trou.jpg
# 'Activité '   rapport_enit_2019.docx	        Untitled0.ipynb

# %%
# !ls "/content/drive/MyDrive/D.v1i.yolo26"
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import torch
print(torch.cuda.is_available())
# Out:
# False

# %%
from ultralytics import YOLO

model = YOLO("yolo12m.pt")

model.train(
    data="/content/drive/MyDrive/D.v1i.yolo26/data.yaml",
    epochs=50,
    imgsz=640
)
# Out:
# ...
# Ultralytics 8.4.22 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (AMD EPYC 7B12)
# ...

# %%
from IPython.display import Image
Image("runs/detect/train/results.png")

# %%
# !ls runs/detect/train/weights
# Out:
# best.pt  last.pt

# %%
from google.colab import files
files.download("runs/detect/train/weights/best.pt")

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train/weights/best.pt")

results = model("/content/drive/MyDrive/1.jpg", save=True)
# Out:
# image 1/1 /content/drive/MyDrive/1.jpg: 640x640 1 DEFECT, 44.0ms
# Speed: 1.8ms preprocess, 44.0ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict

# %%
from IPython.display import Image
Image("/content/runs/detect/predict/1.jpg")

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train/weights/best.pt")

results = model("/content/drive/MyDrive/tache.jpg", save=True)
# Out:
# image 1/1 /content/drive/MyDrive/tache.jpg: 448x640 1 DEFECT, 77.1ms
# Speed: 2.4ms preprocess, 77.1ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict2

# %%
from IPython.display import Image
Image("/content/runs/detect/predict2/tache.jpg")

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train/weights/best.pt")

results = model("/content/drive/MyDrive/trou.jpg", save=True)
# Out:
# image 1/1 /content/drive/MyDrive/trou.jpg: 384x640 2 DEFECTs, 450.1ms
# Speed: 10.7ms preprocess, 450.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/runs/detect/predict3

# %%
from IPython.display import Image
Image("/content/runs/detect/predict3/trou.jpg")
